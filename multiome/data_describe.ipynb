# %%
import numpy as np
import pandas as pd
import os 
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
metadata = pd.read_csv("metadata.csv")
metadata = metadata.drop(['technology'], axis=1)

sns.set_theme(style="whitegrid")

# %%
train = pd.read_hdf('./train_multi_inputs.h5', start= 1024, stop= 2024)
train = train.reset_index(level=0)
train.sample(10)
# Out:
# gene_id       cell_id  GL000194.1:114519-115365  GL000194.1:55758-56597  \
# 495      d8b93d581474                       0.0                     0.0
# 232      0a81dfa52307                       0.0                     0.0
# 348      b4b5a347ea9f                       0.0                     0.0
# 84       d683eff3dcb5                       0.0                     0.0
# 384      f9a14b875c0b                       0.0                     0.0
# 310      e4a00a91405c                       0.0                     0.0
# 809      a6775fec11db                       0.0                     0.0
# 285      6f38c6d07dc2                       0.0                     0.0
# 697      948943eddc3c                       0.0                     0.0
# 654      8bc74d0507f8                       0.0                     0.0
#
# gene_id  GL000194.1:58217-58957  GL000194.1:59535-60431  \
# 495                         0.0                     0.0
# 232                         0.0                     0.0
# 348                         0.0                     0.0
# 84                          0.0                     0.0
# 384                         0.0                     0.0
# 310                         0.0                     0.0
# 809                         0.0                     0.0
# 285                         0.0                     0.0
# 697                         0.0                     0.0
# 654                         0.0                     0.0
#
# gene_id  GL000195.1:119766-120427  GL000195.1:120736-121603  \
# 495                           0.0                       0.0
# 232                           0.0                       0.0
# 348                           0.0                       0.0
# 84                            0.0                       0.0
# 384                           0.0                       0.0
# 310                           0.0                       0.0
# 809                           0.0                       0.0
# 285                           0.0                       0.0
# 697                           0.0                       0.0
# 654                           0.0                       0.0
#
# gene_id  GL000195.1:137437-138345  GL000195.1:15901-16653  \
# 495                           0.0                     0.0
# 232                           0.0                     0.0
# 348                           0.0                     0.0
# 84                            0.0                     0.0
# 384                           0.0                     0.0
# 310                           0.0                     0.0
# 809                           0.0                     0.0
# 285                           0.0                     0.0
# 697                           0.0                     0.0
# 654                           0.0                     0.0
#
# gene_id  GL000195.1:22357-23209  ...  chrY:7722278-7723128  \
# 495                         0.0  ...                   0.0
# 232                         0.0  ...                   0.0
# 348                         0.0  ...                   0.0
# 84                          0.0  ...                   0.0
# 384                         0.0  ...                   0.0
# 310                         0.0  ...                   0.0
# 809                         0.0  ...                   0.0
# 285                         0.0  ...                   0.0
# 697                         0.0  ...                   0.0
# 654                         0.0  ...                   0.0
#
# gene_id  chrY:7723971-7724880  chrY:7729854-7730772  chrY:7731785-7732664  \
# 495                       0.0                   0.0                   0.0
# 232                       0.0                   0.0                   0.0
# 348                       0.0                   0.0                   0.0
# 84                        0.0                   0.0                   0.0
# 384                       0.0                   0.0                   0.0
# 310                       0.0                   0.0                   0.0
# 809                       0.0                   0.0                   0.0
# 285                       0.0                   0.0                   0.0
# 697                       0.0                   0.0                   0.0
# 654                       0.0                   0.0                   0.0
#
# gene_id  chrY:7810142-7811040  chrY:7814107-7815018  chrY:7818751-7819626  \
# 495                       0.0                   0.0                   0.0
# 232                       0.0                   0.0                   0.0
# 348                       0.0                   0.0                   0.0
# 84                        0.0                   0.0                   0.0
# 384                       0.0                   0.0                   0.0
# 310                       0.0                   0.0                   0.0
# 809                       0.0                   0.0                   0.0
# 285                       0.0                   0.0                   0.0
# 697                       0.0                   0.0                   0.0
# 654                       0.0                   0.0                   0.0
#
# gene_id  chrY:7836768-7837671  chrY:7869454-7870371  chrY:7873814-7874709
# 495                       0.0                   0.0                   0.0
# 232                       0.0                   0.0                   0.0
# 348                       0.0                   0.0                   0.0
# 84                        0.0                   0.0                   0.0
# 384                       0.0                   0.0                   0.0
# 310                       0.0                   0.0                   0.0
# 809                       0.0                   0.0                   0.0
# 285                       0.0                   0.0                   0.0
# 697                       0.0                   0.0                   0.0
# 654                       0.0                   0.0                   0.0
#
# [10 rows x 228943 columns]

# %%
target = pd.read_hdf('./train_multi_targets.h5', start= 1024, stop= 2024)
target = target.reset_index(level=0)
target.sample(10)
# Out:
# gene_id       cell_id  ENSG00000121410  ENSG00000268895  ENSG00000175899  \
# 708      a7610e35c1f8         0.000000              0.0              0.0
# 489      0c672ab84b05         0.000000              0.0              0.0
# 945      d025c843722d         0.000000              0.0              0.0
# 640      91b71b88d917         0.000000              0.0              0.0
# 929      c515a76d33be         0.000000              0.0              0.0
# 460      6c0f7e9c8816         0.000000              0.0              0.0
# 35       c7d964f96d77         0.000000              0.0              0.0
# 288      3bb52945ad3c         0.000000              0.0              0.0
# 942      938008084e44         4.567768              0.0              0.0
# 242      5994fd7a54e1         0.000000              0.0              0.0
#
# gene_id  ENSG00000245105  ENSG00000166535  ENSG00000256661  ENSG00000184389  \
# 708                  0.0              0.0              0.0              0.0
# 489                  0.0              0.0              0.0              0.0
# 945                  0.0              0.0              0.0              0.0
# 640                  0.0              0.0              0.0              0.0
# 929                  0.0              0.0              0.0              0.0
# 460                  0.0              0.0              0.0              0.0
# 35                   0.0              0.0              0.0              0.0
# 288                  0.0              0.0              0.0              0.0
# 942                  0.0              0.0              0.0              0.0
# 242                  0.0              0.0              0.0              0.0
#
# gene_id  ENSG00000128274  ENSG00000094914  ...  ENSG00000086827  \
# 708                  0.0         0.000000  ...         0.000000
# 489                  0.0         0.000000  ...         0.000000
# 945                  0.0         0.000000  ...         4.714876
# 640                  0.0         0.000000  ...         0.000000
# 929                  0.0         0.000000  ...         0.000000
# 460                  0.0         4.042179  ...         4.726508
# 35                   0.0         4.660719  ...         0.000000
# 288                  0.0         0.000000  ...         0.000000
# 942                  0.0         0.000000  ...         4.567768
# 242                  0.0         0.000000  ...         0.000000
#
# gene_id  ENSG00000174442  ENSG00000122952  ENSG00000198205  ENSG00000198455  \
# 708             0.000000         4.767096              0.0              0.0
# 489             5.533453         4.844251              0.0              0.0
# 945             0.000000         4.714876              0.0              0.0
# 640             0.000000         0.000000              0.0              0.0
# 929             4.580874         4.580874              0.0              0.0
# 460             0.000000         4.726508              0.0              0.0
# 35              0.000000         0.000000              0.0              0.0
# 288             0.000000         0.000000              0.0              0.0
# 942             0.000000         4.567768              0.0              0.0
# 242             0.000000         0.000000              0.0              0.0
#
# gene_id  ENSG00000070476  ENSG00000203995  ENSG00000162378  ENSG00000159840  \
# 708             4.767096              0.0         4.767096         5.455982
# 489             0.000000              0.0         0.000000         0.000000
# 945             0.000000              0.0         0.000000         0.000000
# 640             0.000000              0.0         0.000000         0.000000
# 929             0.000000              0.0         0.000000         0.000000
# 460             4.042179              0.0         0.000000         0.000000
# 35              5.349125              0.0         0.000000         0.000000
# 288             5.292616              0.0         5.292616         0.000000
# 942             0.000000              0.0         4.567768         0.000000
# 242             4.703001              0.0         4.703001         0.000000
#
# gene_id  ENSG00000074755
# 708             0.000000
# 489             4.844251
# 945             4.714876
# 640             0.000000
# 929             0.000000
# 460             4.726508
# 35              0.000000
# 288             0.000000
# 942             0.000000
# 242             0.000000
#
# [10 rows x 23419 columns]

# %% [markdown]
# # Data Vis

# %%
# Training Set
train_df = pd.read_hdf('./train_multi_inputs.h5', start= 0, stop = 1)
train_df = train_df.reset_index(level=0)
train_df = train_df['cell_id']
train_df = pd.merge(train_df, metadata, how='left',on='cell_id')

for i in range(80):
    temp = pd.read_hdf('./train_multi_inputs.h5', start= 1024 * i + 1, stop=1024 * i + 1024)
    temp = train.reset_index(level=0)
    temp = train['cell_id']

    temp = pd.merge(temp, metadata, how='left',on='cell_id')

    train_df = pd.concat([train_df, temp], ignore_index=True)

# %%
train_df
# Out:
#             cell_id  day  donor cell_type
# 0      56390cf1b95e    2  32606      NeuP
# 1      489111d5e64e    2  32606       HSC
# 2      089158412199    2  32606      MasP
# 3      b7d53e8ec398    2  32606      NeuP
# 4      6ff02eac3340    2  32606       HSC
# ...             ...  ...    ...       ...
# 79996  c65f7110494b    2  32606       HSC
# 79997  cc6b2c30ecf1    2  32606       HSC
# 79998  d1d76346981e    2  32606      MasP
# 79999  e8660f57834a    2  32606      EryP
# 80000  0454296c67bc    2  32606       MkP
#
# [80001 rows x 4 columns]

# %%
# Testing Set
test_df = pd.read_hdf('./test_multi_inputs.h5', start= 0, stop = 1)
test_df = test_df.reset_index(level=0)
test_df = test_df['cell_id']
test_df = pd.merge(test_df, metadata, how='left',on='cell_id')

for i in range(70):
    temp = pd.read_hdf('./test_multi_inputs.h5', start= 1024 * i + 1, stop=1024 * i + 1024)
    temp = temp.reset_index(level=0)
    temp = temp['cell_id']

    temp = pd.merge(temp, metadata, how='left',on='cell_id')

    test_df = pd.concat([test_df, temp], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/dongpochen/Github/Multimodal-Single-Cell-Integration/multiome/data_describe.ipynb Cell 8 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/dongpochen/Github/Multimodal-Single-Cell-Integration/multiome/data_describe.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> test_df = pd.merge(test_df, metadata, how='left',on='cell_id')
#       <a href='vscode-notebook-cell:/Users/dongpochen/Github/Multimodal-Single-Cell-Integration/multiome/data_describe.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> for i in range(70):
# ----> <a href='vscode-notebook-cell:/Users/dongpochen/Github/Multimodal-Single-Cell-Integration/multiome/data_describe.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     temp = pd.read_hdf('./test_multi_inputs.h5', start= 1024 * i + 1, stop=1024 * i + 1024)
#       <a href='vscode-notebook-cell:/Users/dongpochen/Github/Multimodal-Single-Cell-Integration/multiome/data_describe.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>     temp = temp.reset_index(level=0)
#      <a href='vscode-notebook-cell:/Users/dongpochen/Github/Multimodal-Single-Cell-Integration/multiome/data_describe.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     temp = temp['cell_id']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:455, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     450                 raise ValueError(
#     451                     "key must be provided when HDF5 "
#     452                     "file contains multiple datasets."
#     453                 )
#     454         key = candidate_only_group._v_pathname
# --> 455     return store.select(
#     456         key,
#     457         where=where,
#     458         start=start,
#     459         stop=stop,
#     460         columns=columns,
#     461         iterator=iterator,
#     462         chunksize=chunksize,
#     463         auto_close=auto_close,
#     464     )
#     465 except (ValueError, TypeError, KeyError):
#     466     if not isinstance(path_or_buf, HDFStore):
#     467         # if there is an error, close the store if we opened it.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:875, in HDFStore.select(self, key, where, start, stop, columns, iterator, chunksize, auto_close)
#     861 # create the iterator
#     862 it = TableIterator(
#     863     self,
#     864     s,
#    (...)
#     872     auto_close=auto_close,
#     873 )
# --> 875 return it.get_result()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:1943, in TableIterator.get_result(self, coordinates)
#    1940     where = self.where
#    1942 # directly return the result
# -> 1943 results = self.func(self.start, self.stop, where)
#    1944 self.close()
#    1945 return results
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:859, in HDFStore.select.<locals>.func(_start, _stop, _where)
#     858 def func(_start, _stop, _where):
# --> 859     return s.read(start=_start, stop=_stop, where=_where, columns=columns)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:3213, in BlockManagerFixed.read(self, where, columns, start, stop)
#    3210     dfs.append(df)
#    3212 if len(dfs) > 0:
# -> 3213     out = concat(dfs, axis=1)
#    3214     out = out.reindex(columns=items, copy=False)
#    3215     return out
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:595, in _Concatenator.get_result(self)
#     591             indexers[ax] = obj_labels.get_indexer(new_labels)
#     593     mgrs_indexers.append((obj._mgr, indexers))
# --> 595 new_data = concatenate_managers(
#     596     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597 )
#     598 if not self.copy:
#     599     new_data._consolidate_inplace()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/concat.py:202, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     195 # Assertions disabled for performance
#     196 # for tup in mgrs_indexers:
#     197 #    # caller is responsible for ensuring this
#     198 #    indexers = tup[1]
#     199 #    assert concat_axis not in indexers
#     201 if concat_axis == 0:
# --> 202     return _concat_managers_axis0(mgrs_indexers, axes, copy)
#     204 mgrs_indexers = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers)
#     206 # Assertion disabled for performance
#     207 # assert all(not x[1] for x in mgrs_indexers)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/concat.py:278, in _concat_managers_axis0(mgrs_indexers, axes, copy)
#     276     nb = blk.copy(deep=False)
#     277 elif copy:
# --> 278     nb = blk.copy()
#     279 else:
#     280     # by slicing instead of copy(deep=False), we get a new array
#     281     #  object, see test_concat_copy
#     282     nb = blk.getitem_block(slice(None))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:643, in Block.copy(self, deep)
#     641 values = self.values
#     642 if deep:
# --> 643     values = values.copy()
#     644 return type(self)(values, placement=self._mgr_locs, ndim=self.ndim)
#
# KeyboardInterrupt:
